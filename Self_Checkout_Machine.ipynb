# %% [markdown]
# <a href="https://colab.research.google.com/github/linglingshere/Self-Checkout-Machine/blob/main/Self_Checkout_Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Program untuk kegiatan jual beli di toko alat tulis
#Program ini menggunakan
# while loop :
# - pengulangan program untuk setiap konsumen yang berkunjung
# - pengulangan program ketika pembayaran tidak mencukupi
# if-elif-else :
# - percabangan apakah ingin membeli sesuatu atau tidak dan apakah ada yang ingin ditambahkan
# - percabangan ketika memilih barang-barang yang akan di beli

# kode cetak tebal : '\033[1m'
# kode warna ungu : '\033[95m'
# kode warna merah : '\033[91m'
# kode warna biru : '\033[94m'
# kode mengakhiri warna : '\033[0m'

#my_list ini merupakan daftar variabel- variabel barang yang dijual dengan setiap barangnya dipisahkan tanda koma
# ketika ingin digunakan bisa dengan menyebutkan my_list[urutan]. Urutan dimulai dari angka 0.

# %%
my_list = ['Buku Tulis A5''\033[1m''(aa)''\033[0m' '  : ''\033[95m''\033[1m'"Rp 7.000"'\033[0m',
           'Buku Tulis B5''\033[1m''(ab)''\033[0m' '  : ''\033[95m''\033[1m'"Rp 10.000"'\033[0m',
           'Correction Tape''\033[1m''(ac)''\033[0m' ': ''\033[95m''\033[1m'"Rp 12.000"'\033[0m',
           'Kotak Pensil''\033[1m''(ad)''\033[0m'   '   : ''\033[95m''\033[1m'"Rp 15.000"'\033[0m',
           'Pensil''\033[1m''(ae)''\033[0m'         '         : ''\033[95m''\033[1m'"Rp 2.000"'\033[0m',
           'Penghapus''\033[1m''(af)''\033[0m'      '      : ''\033[95m''\033[1m'"Rp 2.000"'\033[0m',
           'Penggaris''\033[1m''(ag)''\033[0m'      '      : ''\033[95m''\033[1m'"Rp 2.000"'\033[0m',
           'Pulpen''\033[1m''(ah)''\033[0m'         '         : ''\033[95m''\033[1m'"Rp 3.000"'\033[0m',
           'Spidol ''\033[1m''(ai)''\033[0m'   '        : ''\033[95m''\033[1m'"Rp 4.000"'\033[0m',
           'Sticky Notes''\033[1m''(aj)''\033[0m'   '   : ''\033[95m''\033[1m'"Rp 5.000"'\033[0m']

# %%
#Daftar barang yang disediakan toko, yang masing masing diberi kode sebagai berikut:
aa = 'Buku Tulis A5'
ab = 'Buku Tulis B5'
ac = 'Correction Tape'
ad = 'Kotak Pensil'
ae = 'Pensil'
af = 'Penghapus'
ag = 'Penggaris'
ah = 'Pulpen'
ai = 'Spidol'
aj = 'Sticky Notes'

# %% [markdown]
# Membuat Format Nota Pembayaran

# %%
# Penggunaan while loop untuk setiap konsumen yang datang berkunjung
# Program ini akan berjalan tak hingga banyak kali karena program selalu bernilai True

while True:
    print()
    print()
    print()
    print('====================================================================================================')
    print('{:^100}'.format('\033[1m'"- TOKO ALAT TULIS TADIKA MESRA -"'\033[0m')) #menggunakan spasi sebanyak 100
    print('{:^100}'.format('\033[1m'"Jalan Durian Runtuh No.2904, Yogyakarta"'\033[0m'))
    print()
    print('Selamat Datang')
    print('\033[1m''Toko Tadika Mesra ini menyediakan:''\033[0m')
    print()
    print("1. ", my_list[0])
    print("2. ", my_list[1])
    print("3. ", my_list[2])
    print("4. ", my_list[3])
    print("5. ", my_list[4])
    print("6. ", my_list[5])
    print("7. ", my_list[6])
    print("8. ", my_list[7])
    print("9. ", my_list[8])
    print("10.", my_list[9])
    print('\033[1m' 'Note : kode ditulis dengan huruf kecil' '\033[0m')
    print()

    tanya = input('\033[94m''\033[1m''Apakah anda ingin membeli sesuatu?(ya/tidak) ''\033[0m') #Mengkombinasikan warna biru dan cetak tebal
    tanya = tanya.upper()               #mengubah seluruh teks dari input menjadi huruf kapital
    if tanya == 'YA':
        print()
        a = print('\033[1m'"BARANG 1:"'\033[0m')
        p1 = input('Kode barang yang ingin dibeli: ')
        q1 = int(input('Jumlah barang: '))
        if p1 == 'ae':
            p1 = ae
            h = 2000
        elif p1 == 'af':
            p1 = af
            h = 2000
        elif p1 =='ag':
            p1 = ag
            h = 2000
        elif p1 == 'aa' :
            p1 = aa
            h = 7000
        elif p1 == 'ab' :
            p1 = ab
            h = 10000
        elif p1 == 'ac' :
            p1 = ac
            h = 12000
        elif p1 == 'ad':
            p1 = ad
            h = 15000
        elif p1 == 'aj' :
            p1 = aj
            h = 5000
        elif p1 == 'ah' :
            p1 = ah
            h = 3000
        else :
            p1 = ai
            h = 4000

        harga_a = h * q1           #h adalah harganya dan q1 adalah jumlah barangnya
        print()

        tanya2 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya2 = tanya2.upper()
        print()
        if tanya2 == 'YA':
            b = print('\033[1m'"BARANG 2:"'\033[0m')
            p2 = input('Kode barang yang ingin dibeli: ')
            q2 = int(input('Jumlah barang: '))
            if p2 == 'aa' :
                p2 = aa
                h = 7000
            elif p2 == 'ab' :
                p2 = ab
                h = 10000
            elif p2 == 'ac' :
                p2 = ac
                h = 12000
            elif p2 == 'ad':
                p2 = ad
                h = 15000
            elif p2 == 'aj' :
                p2 = aj
                h = 5000
            elif p2 == 'ah' :
                p2 = ah
                h = 3000
            elif p2 == 'ai' :
                p2 = ai
                h = 4000
            elif p2 == 'ae':
                p2 = ae
                h = 2000
            elif p2 =='af':
                p2 = af
                h = 2000
            else :
                p2 = ag
                h = 2000
            harga_b = h * q2

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total Harga        : Rp',harga_a)
            y = int(input('Nominal pembayaran : Rp '))

            #penggunaan while digunakan untuk kondisi ketika nominal pembayaran yang diinputkan kurang dari total harga
            #loop akan terus berulang hingga nominal pembayaran sama dengan atau lebih besar dari total harga
            while y < harga_a:
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - harga_a

            print('Kembalian          : Rp',kembalian)
            print()
            print()
            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue #digunakan agar while loop diulang dari awal untuk konsumen selanjutnya
        print()

        tanya3 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ' '\033[91m''\033[1m''\033[0m')
        tanya3 = tanya3.upper()
        print()
        if tanya3 == 'YA':
            c = print('\033[1m'"BARANG 3:"'\033[0m')
            p3 = input('Kode barang yang ingin dibeli: ')
            q3 = int(input('Jumlah barang: '))
            if p3 == 'aa' :
                p3 = aa
                h = 7000
            elif p3 == 'ab' :
                p3 = ab
                h = 10000
            elif p3 == 'ac' :
                p3 = ac
                h = 12000
            elif p3 == 'ad':
                p3 = ad
                h = 15000
            elif p3 == 'aj' :
                p3 = aj
                h = 5000
            elif p3 == 'ah' :
                p3 = ah
                h = 3000
            elif p3 == 'ai' :
                p3 = ai
                h = 4000
            elif 'ae':
                p3 = ae
                h = 2000
            elif 'af':
                p3 = af
                h = 2000
            else :
                p3 = ag
                h = 2000
            harga_c = h * q3

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))

            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = int(y)-int(total_harga)
            print('Kembalian          : Rp',kembalian)
            print()
            print()
            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        print()
        tanya4 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya4 = tanya4.upper()
        print()
        if tanya4 == 'YA':
            d = print('\033[1m'"BARANG 4:"'\033[0m')
            p4 = input('Kode barang yang ingin dibeli: ')
            q4 = int(input('Jumlah barang: '))
            if p4 == 'aa' :
                p4 = aa
                h = 7000
            elif p4 == 'ab' :
                p4 = ab
                h = 10000
            elif p4 == 'ac' :
                p4 = ac
                h = 12000
            elif p4 == 'ad':
                p4 = ad
                h = 15000
            elif p4 == 'aj' :
                p4 = aj
                h = 5000
            elif p4 == 'ah' :
                p4 = ah
                h = 3000
            elif p4 == 'ai' :
                p4 = ai
                h = 4000
            elif p4 == 'ae':
                p4 = ae
                h = 2000
            elif p4 =='af':
                p4 = af
                h = 2000
            else :
                p4 = ag
                h = 2000
            harga_d = h * q4

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()
            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        print()
        tanya5 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya5 = tanya5.upper()
        print()
        if tanya5 == 'YA':
            e = print('\033[1m'"BARANG 5:"'\033[0m')
            p5 = input('Kode barang yang ingin dibeli: ')
            q5 = int(input('Jumlah barang: '))
            if p5 == 'aa' :
                p5 = aa
                h = 7000
            elif p5 == 'ab' :
                p5 = ab
                h = 10000
            elif p5 == 'ac' :
                p5 = ac
                h = 12000
            elif p5 == 'ad':
                p5 = ad
                h = 15000
            elif p5 == 'aj' :
                p5 = aj
                h = 5000
            elif p5 == 'ah' :
                p5 = ah
                h = 3000
            elif p5 == 'ai' :
                p5 = ai
                h = 4000
            elif p5 == 'ae':
                p5 = ae
                h = 2000
            elif p5 =='af':
                p5 = af
                h = 2000
            else :
                p5 = ag
                h = 2000
            harga_e = h * q5

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print()

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        print()
        tanya6 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya6 = tanya6.upper()
        print()
        if tanya6 == 'YA':
            f = print('\033[1m'"BARANG 6:"'\033[0m')
            p6 = input('Kode barang yang ingin dibeli: ')
            q6 = int(input('Jumlah barang: '))
            if p6 == 'aa' :
                p6 = aa
                h = 7000
            elif p6 == 'ab' :
                p6 = ab
                h = 10000
            elif p6 == 'ac' :
                p6 = ac
                h = 12000
            elif p6 == 'ad':
                p6 = ad
                h = 15000
            elif p6 == 'aj' :
                p6 = aj
                h = 5000
            elif p6 == 'ah' :
                p6 = ah
                h = 3000
            elif p6 == 'ai' :
                p6 = ai
                h = 4000
            elif p6 == 'ae':
                p6 = ae
                h = 2000
            elif p6 =='af':
                p6 = af
                h = 2000
            else :
                p6 = ag
                h = 2000
            harga_f = h * q6

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print()

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('\033[1m''BARANG 5:''\033[0m')
            print('Nama Barang        :',p5)
            print('Jumlah             :',q5)
            print('Total              : Rp',harga_e)

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d + harga_e
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        print()
        tanya7 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya7 = tanya7.upper()
        print()
        if tanya7 == 'YA':
            g = print('\033[1m'"BARANG 7:"'\033[0m')
            p7 = input('Kode barang yang ingin dibeli: ')
            q7 = int(input('Jumlah barang: '))
            if p7 == 'aa' :
                p7 = aa
                h = 7000
            elif p7 == 'ab' :
                p7 = ab
                h = 10000
            elif p7 == 'ac' :
                p7 = ac
                h = 12000
            elif p7 == 'ad':
                p7 = ad
                h = 15000
            elif p7 == 'aj' :
                p7 = aj
                h = 5000
            elif p7 == 'ah' :
                p7 = ah
                h = 3000
            elif p7 == 'ai' :
                p7 = ai
                h = 4000
            elif p7 == 'ae':
                p7 = ae
                h = 2000
            elif p7 =='af':
                p7 = af
                h = 2000
            else :
                p7 = ag
                h = 2000
            harga_g = h * q7

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('\033[1m''BARANG 5:''\033[0m')
            print('Nama Barang        :',p5)
            print('Jumlah             :',q5)
            print('Total              : Rp',harga_e)
            print()

            print('\033[1m''BARANG 6:''\033[0m')
            print('Nama Barang        :',p6)
            print('Jumlah             :',q6)
            print('Total              : Rp',harga_f)
            print()

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d + harga_e + harga_f
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))

            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        print()
        tanya8 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya8 = tanya8.upper()
        print()
        if tanya8 == 'YA':
            z = print('\033[1m'"BARANG 8:"'\033[0m')
            p8 = input('Kode barang yang ingin dibeli: ')
            q8 = int(input('Jumlah barang: '))
            if p8 == 'aa' :
                p8 = aa
                h = 7000
            elif p8 == 'ab' :
                p8 = ab
                h = 10000
            elif p8 == 'ac' :
                p8 = ac
                h = 12000
            elif p8 == 'ad':
                p8 = ad
                h = 15000
            elif p8 == 'aj' :
                p8 = aj
                h = 5000
            elif p8 == 'ah' :
                p8 = ah
                h = 3000
            elif p8 == 'ai' :
                p8 = ai
                h = 4000
            elif p8 == 'ae':
                p8 = ae
                h = 2000
            elif p8 =='af':
                p8 = af
                h = 2000
            else :
                p8 = ag
                h = 2000
            harga_z = h * q8
            print()

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print()

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('\033[1m''BARANG 5:''\033[0m')
            print('Nama Barang        :',p5)
            print('Jumlah             :',q5)
            print('Total              : Rp',harga_e)
            print()

            print('\033[1m''BARANG 6:''\033[0m')
            print('Nama Barang        :',p6)
            print('Jumlah             :',q6)
            print('Total              : Rp',harga_f)
            print()

            print('\033[1m''BARANG 7:''\033[0m')
            print('Nama Barang        :',p7)
            print('Jumlah             :',q7)
            print('Total              : Rp',harga_g)
            print()

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d + harga_e + harga_f + harga_g
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        tanya9 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya9 = tanya9.upper()
        print()
        if tanya9 == 'YA':
            i = print('\033[1m'"BARANG 9:"'\033[0m')
            p9 = input('Kode barang yang ingin dibeli: ')
            q9 = int(input('Jumlah barang: '))
            if p9 == 'aa' :
                p9 = aa
                h = 7000
            elif p9 == 'ab' :
                p9 = ab
                h = 10000
            elif p9 == 'ac' :
                p9 = ac
                h = 12000
            elif p9 == 'ad':
                p9 = ad
                h = 15000
            elif p9 == 'aj' :
                p9 = aj
                h = 5000
            elif p9 == 'ah' :
                p9 = ah
                h = 3000
            elif p9 == 'ai' :
                p9 = ai
                h = 4000
            elif p9 == 'ae':
                p9 = ae
                h = 2000
            elif p9 =='af':
                p9 = af
                h = 2000
            else :
                p9 = ag
                h = 2000
            harga_i = h * q9


        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print()

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('\033[1m''BARANG 5:''\033[0m')
            print('Nama Barang        :',p5)
            print('Jumlah             :',q5)
            print('Total              : Rp',harga_e)
            print()

            print('\033[1m''BARANG 6:''\033[0m')
            print('Nama Barang        :',p6)
            print('Jumlah             :',q6)
            print('Total              : Rp',harga_f)
            print()

            print('\033[1m''BARANG 7:''\033[0m')
            print('Nama Barang        :',p7)
            print('Jumlah             :',q7)
            print('Total              : Rp',harga_g)
            print()

            print('\033[1m''BARANG 8:''\033[0m')
            print('Nama Barang        :',p8)
            print('Jumlah             :',q8)
            print('Total              : Rp',harga_z)
            print()

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d + harga_e + harga_f + harga_g + harga_z
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        print()
        tanya10 = input( '\033[91m''\033[1m''Apakah ada lagi yang ingin anda beli?(ya/tidak) ''\033[91m''\033[1m''\033[0m')
        tanya10 = tanya10.upper()
        print()
        if tanya10 == 'YA':
            i = print('\033[1m'"BARANG 10:"'\033[0m')
            p10 = input('Kode barang yang ingin dibeli: ')
            q10 = int(input('Jumlah barang: '))
            if p10 == 'aa' :
                p10 = aa
                h = 7000
            elif p10 == 'ab' :
                p10 = ab
                h = 10000
            elif p10 == 'ac' :
                p10 = ac
                h = 12000
            elif p10 == 'ad':
                p10 = ad
                h = 15000
            elif p10 == 'aj' :
                p10 = aj
                h = 5000
            elif p10 == 'ah' :
                p10 = ah
                h = 3000
            elif p10 == 'ai' :
                p10 = ai
                h = 4000
            elif p10 == 'ae':
                p10 = ae
                h = 2000
            elif p10 =='af':
                p10 = af
                h = 2000
            else :
                p10 = ag
                h = 2000
            harga_j = h * q10

            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print()

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('\033[1m''BARANG 5:''\033[0m')
            print('Nama Barang        :',p5)
            print('Jumlah             :',q5)
            print('Total              : Rp',harga_e)
            print()

            print('\033[1m''BARANG 6:''\033[0m')
            print('Nama Barang        :',p6)
            print('Jumlah             :',q6)
            print('Total              : Rp',harga_f)
            print()

            print('\033[1m''BARANG 7:''\033[0m')
            print('Nama Barang        :',p7)
            print('Jumlah             :',q7)
            print('Total              : Rp',harga_g)
            print()

            print('\033[1m''BARANG 8:''\033[0m')
            print('Nama Barang        :',p8)
            print('Jumlah             :',q8)
            print('Total              : Rp',harga_z)
            print()

            print('\033[1m''BARANG 9:''\033[0m')
            print('Nama Barang        :',p9)
            print('Jumlah             :',q9)
            print('Total              : Rp',harga_i)
            print()

            print('\033[1m''BARANG 10:''\033[0m')
            print('Nama Barang        :',p10)
            print('Jumlah             :',q10)
            print('Total              : Rp',harga_j)
            print()

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d + harga_e + harga_f + harga_g + harga_z + harga_i + harga_j
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

        else :
            print()
            print('{:^40}'.format('\033[1m'"* STRUK BELANJA *"'\033[0m'))
            print()
            print('\033[1m''BARANG 1:''\033[0m')
            print('Nama Barang        :',p1)
            print('Jumlah             :',q1)
            print('Total              : Rp',harga_a)
            print()

            print('\033[1m''BARANG 2:''\033[0m')
            print('Nama Barang        :',p2)
            print('Jumlah             :',q2)
            print('Total              : Rp',harga_b)
            print()

            print('\033[1m''BARANG 3:''\033[0m')
            print('Nama Barang        :',p3)
            print('Jumlah             :',q3)
            print('Total              : Rp',harga_c)
            print()

            print('\033[1m''BARANG 4:''\033[0m')
            print('Nama Barang        :',p4)
            print('Jumlah             :',q4)
            print('Total              : Rp',harga_d)
            print()

            print('\033[1m''BARANG 5:''\033[0m')
            print('Nama Barang        :',p5)
            print('Jumlah             :',q5)
            print('Total              : Rp',harga_e)
            print()

            print('\033[1m''BARANG 6:''\033[0m')
            print('Nama Barang        :',p6)
            print('Jumlah             :',q6)
            print('Total              : Rp',harga_f)
            print()

            print('\033[1m''BARANG 7:''\033[0m')
            print('Nama Barang        :',p7)
            print('Jumlah             :',q7)
            print('Total              : Rp',harga_g)
            print()

            print('\033[1m''BARANG 8:''\033[0m')
            print('Nama Barang        :',p8)
            print('Jumlah             :',q8)
            print('Total              : Rp',harga_z)
            print()

            print('\033[1m''BARANG 9:''\033[0m')
            print('Nama Barang        :',p9)
            print('Jumlah             :',q9)
            print('Total              : Rp',harga_i)
            print()

            print('_______________________________________')
            print()
            total_harga = harga_a + harga_b + harga_c + harga_d + harga_e + harga_f + harga_g + harga_z + harga_i
            print('Total Harga        : Rp', total_harga)
            y = int(input('Nominal pembayaran : Rp '))
            while y < total_harga :
                print('\033[91m''\033[1m' 'Nominal pembayaran tidak mencukupi' '\033[91m''\033[1m''\033[0m')
                print('\033[91m''\033[1m' 'Harap coba lagi' '\033[91m''\033[1m''\033[0m')
                y = int(input('Nominal pembayaran : Rp '))

            kembalian = y - total_harga
            print('Kembalian          : Rp',kembalian)
            print()
            print()

            print('{:^100}'.format('\033[1m'"- TERIMA KASIH ATAS KUNJUNGAN ANDA -"'\033[0m'))
            continue

    else :
        print('Oke, Terima Kasih')
# Out:
# ...
#                               - TOKO ALAT TULIS TADIKA MESRA -
#                           Jalan Durian Runtuh No.2904, Yogyakarta
#
# Selamat Datang
# Toko Tadika Mesra ini menyediakan:
#
# 1.  Buku Tulis A5(aa)  : Rp 7.000
# 2.  Buku Tulis B5(ab)  : Rp 10.000
# 3.  Correction Tape(ac): Rp 12.000
# 4.  Kotak Pensil(ad)   : Rp 15.000
# 5.  Pensil(ae)         : Rp 2.000
# 6.  Penghapus(af)      : Rp 2.000
# 7.  Penggaris(ag)      : Rp 2.000
# 8.  Pulpen(ah)         : Rp 3.000
# 9.  Spidol (ai)        : Rp 4.000
# 10. Sticky Notes(aj)   : Rp 5.000
# Note : kode ditulis dengan huruf kecil
#
# Oke, Terima Kasih
#
#
#
# ...
#                               - TOKO ALAT TULIS TADIKA MESRA -
#                           Jalan Durian Runtuh No.2904, Yogyakarta
#
# Selamat Datang
# Toko Tadika Mesra ini menyediakan:
#
# 1.  Buku Tulis A5(aa)  : Rp 7.000
# 2.  Buku Tulis B5(ab)  : Rp 10.000
# 3.  Correction Tape(ac): Rp 12.000
# 4.  Kotak Pensil(ad)   : Rp 15.000
# 5.  Pensil(ae)         : Rp 2.000
# ...
